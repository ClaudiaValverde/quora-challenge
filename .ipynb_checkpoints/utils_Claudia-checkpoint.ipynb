# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn import *
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from utils import *
sns.set()

# %% [markdown]
# ## Load Data

# %%
# use this to train and VALIDATE your solution
train_df = pd.read_csv("../nlp_deliv1_materials/quora_train_data.csv")

# %%
A_df, te_df = model_selection.train_test_split(train_df, test_size=0.05, random_state=123)
tr_df, va_df = model_selection.train_test_split(A_df, test_size=0.05, random_state=123)
print('tr_df.shape=',tr_df.shape)
# Out:
# tr_df.shape= (291897, 6)

# %%
tr_df.head()
# Out:
#             id    qid1    qid2  \
# 61482   125898  203030  203031
# 131546   36249   66113   66114
# 22927   199864  301469  301470
# 183520  277339   17728  138400
# 67694   392907  525647  525648
#
#                                                 question1  \
# 61482   Is Java or C++ or C the most popular language ...
# 131546  How do you convert direct speech into reported...
# 22927                  Where can I buy used wine barrels?
# 183520  What was the best day of your life? (Excluding...
# 67694                           How is web-work.in works?
#
#                                                 question2  is_duplicate
# 61482   How do I develop a software which will have a ...             0
# 131546  I feel weak at spoken English. I have sentence...             0
# 22927                Where can you buy used wine barrels?             1
# 183520       What is the Best Day of your life till date?             1
# 67694                    How do I get web designing work?             0

# %%
va_df.head()
# Out:
#             id    qid1    qid2  \
# 146205  378301  509685   56699
# 99373   332237  459221  303879
# 292307  283851  100550   99720
# 73776   306170   87025  429632
# 256938   24445   14806   12515
#
#                                                 question1  \
# 146205  Who is more dishonest, Donald Trump or Hillary...
# 99373    What are the healthiest foods to eat for dinner?
# 292307                       Can a dog take baby aspirin?
# 73776                          What is churchofsatan.com?
# 256938  Why MS Dhoni left captaincy though he was a su...
#
#                                                 question2  is_duplicate
# 146205  Would you rather vote for Donald Trump or Hill...             0
# 99373                       Which is the healthiest food?             0
# 292307  Is it safe to give my dog a baby aspirin and h...             1
# 73776                               What is Loadteam.com?             0
# 256938  Why does M.S Dhoni left captaincy for ODI and ...             1

# %% [markdown]
# ## Analysis of the data

# %%
# Group by 'is_duplicate' and count the number of IDs for training and validation data
tr_counts = tr_df.groupby('is_duplicate')['id'].count()
va_counts = va_df.groupby('is_duplicate')['id'].count()

# Create a grid of subplots with 1 row and 2 columns
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot training data counts
tr_counts.plot(kind='bar', ax=axs[0], color='lightblue')
axs[0].set_title('Training Data')

# Plot validation data counts
va_counts.plot(kind='bar', ax=axs[1], color='lightgreen')
axs[1].set_title('Validation Data')

# Set common labels
for ax in axs:
    ax.set_xlabel('is_duplicate')
    ax.set_ylabel('Count')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
qids = pd.Series(tr_df['qid1'].to_list() + tr_df['qid2'].to_list())
num_unique_questions = len(np.unique(qids))
non_unique_questions = np.sum(qids.value_counts() > 1)
percentage_non_unique_questions = ( non_unique_questions / num_unique_questions ) * 100

print("Statistics on Question IDs \n","---"*35)
print(f"Number of Unique Questions: {num_unique_questions}")
print(f"Number of Non-Unique Questions: {non_unique_questions}")
print(f"Percentage of Non-Unique Questions: {percentage_non_unique_questions:.2f}%")
print(f"Maximum Times a Question Got Repeated: {qids.value_counts().iloc[0]}")
# Out:
# Statistics on Question IDs
#  ---------------------------------------------------------------------------------------------------------
# Number of Unique Questions: 414213
# Number of Non-Unique Questions: 75805
# Percentage of Non-Unique Questions: 18.30%
# Maximum Times a Question Got Repeated: 125

# %%
pair_duplicates = tr_df[['qid1', 'qid2', 'is_duplicate']].groupby(['qid1', 'qid2']).count().reset_index()
num_duplicated_questions = pair_duplicates.shape[0] - tr_df.shape[0]
print(f"Number of duplicated questions: {num_duplicated_questions}")
# Out:
# Number of duplicated questions: 0

# %%
# fer funció per mirar max sequence len

# %% [markdown]
# ## TF-IDF
# Is a measure that can be used to build feature vectors. It measures the importance of a word to a document corpus.
#
# **TF**: *term frequency*,  emphasizes words taht appear frequently in a geiven document.
#
# **IDF**: *inverse document frequency*, empasizes words that appear rarely in a set of documents.

# %%
# preprocessing
# filling Nan values as ''

df = tr_df.fillna('')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

questions = list(df['question1']) + list(df['question2'])
tfidf = TfidfVectorizer()
X_train_tfidf = tfidf.fit(questions)

# %%
X_tr_q1q2 = get_features_from_df(df, tfidf) # it converts list as strings

# %%
# training a simple model
logistic = sklearn.linear_model.LogisticRegression(solver="liblinear",
                                                   random_state=123)
logistic.fit(X_tr_q1q2, y_train)
# Out:
# LogisticRegression(random_state=123, solver='liblinear')

# %%
train_model = evaluate_model(X_tr_q1q2, y_train, model=logistic, display=True)
# Out:
# METRICS:
#  ------------------------------------------------------------------------------------------
# Accuracy:  0.7944823002634491
# F1:  0.6905562662485041
# Precision:  0.7759462122529415
# Recall:  0.622096859636242
# ROC AUC:  0.758611615528221
#
#  CLASSIFICATION REPORT:
#  ------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.80      0.90      0.85    184298
#     Positive       0.78      0.62      0.69    107599
#
#     accuracy                           0.79    291897
#    macro avg       0.79      0.76      0.77    291897
# weighted avg       0.79      0.79      0.79    291897
#
# CONFUSION MATRIX:
#  ------------------------------------------------------------------------------------------

# %%
# not a bad performance with TF-IDF, although CountVectorizer seems better

# %%
# cosine similarity

def compute_cosine_similarity(embedding1, embedding2):
    """
    Computes the cosine similarity between two given word embeddings.

    Args:
        embedding1 (numpy.ndarray or None): The first word embedding.
        embedding2 (numpy.ndarray or None): The second word embedding.

    Returns:
        float or None: The cosine similarity between the two embeddings. If either of the embeddings is None, returns None.
    """
    # Check if either of the embeddings is None
    if embedding1 is None or embedding2 is None:
        return None
    else:
        # Compute the cosine similarity between the two embeddings
        return 1 - cosine(embedding1, embedding2)

# %% [markdown]
# ## Edit Distance
#
# Edit distance computes X .... bla bla bla
#
# Our implementation returns 1 column (feature) for the distance between the pair of questions.

# %%
# %load_ext Cython

# %%
# %%cython --annotate
#
# def cy_create_memoization_table(str X, str Y):
#     cdef int i, j, del_char, ins_char, sub_char, Z
#     cdef int len_x = len(X)
#     cdef int len_y = len(Y)
#     cdef int [:, :] D =  np.zeros((len_x + 1, len_y + 1), dtype=np.int32)
#
#     for i in range(len_x+1):
#         D[i,0] = i
#
#     for j in range(len_y+1):
#         D[0,j] = j
#
#     for i in range(1, len_x + 1):
#         for j in range(1, len_y + 1):
#             del_char = D[i-1,j] + 1
#             ins_char = D[i,j-1] + 1
#
#             if X[i-1] == Y[j-1]:
#                 Z = 0
#             else:
#                 Z = 1
#             sub_char = D[i-1,j-1] + Z
#
#             D[i,j] = min(del_char, ins_char, sub_char)
#
#     return D
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.21 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_d98a3886ff177979a317c67c9bd1c0d3.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-colo

# %%
# eucledian distance
def edit_distance(x,y):
    return cy_create_memoization_table(x,y)[-1,-1]

# %%
# edit distance only works for str type
edit_distances = tr_df.apply(lambda row: edit_distance(str(row['question1']), str(row['question2'])), axis=1)

# %%
edit_distances
# Out:
# 61482     70
# 131546    84
# 22927      3
# 183520    37
# 67694     17
#           ..
# 231903    52
# 115066     4
# 35776     82
# 300894    66
# 61325     43
# Length: 291897, dtype: int64

# %% [markdown]
# ## Jaccard Similarity
# also known as Jaccard index, is a statistic to measure the similarity between two data sets. It is measured as the size of the intersection of two sets divided by the size of their union. Jaccard similarity can be used in natural language processing to compare texts, text samples, or even individual words.

# %%
# Define a function to compute Jaccard similarity between two strings
def jaccard_similarity(s1, s2):
    set1 = set(str(s1).lower().split())  # Convert string to set of lowercase words
    set2 = set(str(s2).lower().split())  # Convert string to set of lowercase words
    intersection = len(set1.intersection(set2))  # Compute intersection
    union = len(set1.union(set2))  # Compute union
    return intersection / union if union != 0 else 0  # Compute Jaccard similarity

# %%
jaccard_similarity = tr_df.apply(lambda row: jaccard_similarity(row['question1'], row['question2']), axis=1)

# %%
jaccard_similarity
# Out:
# 61482     0.153846
# 131546    0.000000
# 22927     0.750000
# 183520    0.352941
# 67694     0.100000
#             ...
# 231903    0.350000
# 115066    0.750000
# 35776     0.185185
# 300894    0.037037
# 61325     0.545455
# Length: 291897, dtype: float64

# %% [markdown]
# ## Feature Hashing
#
# The class FeatureHasher is a high-speed, low-memory vectorizer that uses a technique known as feature hashing, or the “hashing trick”. Instead of building a hash table of the features encountered in training, as the vectorizers do, instances of FeatureHasher apply a hash function to the features to determine their column index in sample matrices directly

# %%
y_train = tr_df['is_duplicate']

# %%
questions = list(tr_df['question1']) + list(tr_df['question2'])
# Out:
# ['Is Java or C++ or C the most popular language amongst startups for backend development?',
#  'How do you convert direct speech into reported speech and vice versa including all cases?',
#  'Where can I buy used wine barrels?',
#  'What was the best day of your life? (Excluding family things like births)',
#  'How is web-work.in works?',
#  'How many active Twitter users are there in the US?',
#  'Do you have a secret crush on someone on Quora?',
#  'What is a good anime?',
#  'Can I claim HRA during ITR Filing?',
#  'What is the longest roller coaster in the United Kingdom and how does it compare to the longest roller coaster in Canada?',
#  'Do Chinese people eat babies/fetuses?',
#  'Is it safe to cook using aluminum foil wrap in direct contact with food?',
#  'Whey is the sky blue?',
#  'As a black woman how do I attract white men?',
#  "Where's the best place to learn how to hack?",
#  'What are the requirements for being an online tutor? How do I teach online?',
#  'Should "furniture" be followed by "is" or "are"?',
#  'What could be the consequences of recalling 500 and 1000 rupee note?',
#  'How do I heat up my laptop?',
#  'How do I get girls to chase me?',
#  "What do you hate about Toptal's interviewing process?",
#  'What are dimension work?',
#  'Which is better MacBook or MacBook Pro or MacBook Air? Or should i buy Windows PC?',
#  'I wrote a letter, asking for donations from companies and philanthropist to help pay off $100,000 private student loan debt. Where should I send it?',
#  'How do I learn how to invest in stock market and mutual funds?',
#  'Who do you love and why?',
#  'What is currently happening in Turkey?',
#  "Can someone still get your message on snapchat if they haven't read it yet and you deactivated your account?",
#  'How long does it take for a human body to completely decompose?',
#  'What is the most inspiring movie you have ever seen?',
#  'Which automation testing tool is best for mobile testing?',
#  'Capgemini is recruiting through cocubes.com. Can someone tell me whats the cut-off score in pre-assess to get shortlisted for the written exam?',
#  'I am interested in research. What is the GATE CSIR JRF?',
#  'Would demonetization of 500 and 1000 rupee notes actually help in curbing black money in India?',
#  'How can I crack the civil exam?',
#  "What is Hillary Clinton's stand on relations with India?",
#  'How can I sign out from the Gmail app on my Android phone?',
#  'Can casteism ever end in India?',
#  'Why do people give presents/gifts?',
#  'Did Bahaullah perform miracles?',
#  'Why does CloudFoundry use NATS (a  specially written messaging system) whereas OpenStack uses AMQP?',
#  'Do you know any bikers group or individuals who practice stunts in pune on bike?',
#  'How do I be successful in life?',
#  'What is a good website for free ebooks?',
#  "I'm not exclusive with a girl, but we agreed to be faithful. Just found out she was making out with someone else. What should I do?",
#  'Who should prepare for SSC CGL?',
#  'What are the best apps for writing journal on my programming activities?',
#  'How can you make sour cream from cream cheese?',
#  'How can I get out of my comfort zone and be myself at the same time?',
#  'Are more small-minded and egocentric and perhaps also manipulative people more likely to think they are "omniscient"?',
#  'Is it justifiable to leave your parents for love?',
#  'Why do messages on Facebook messenger stay sent? Is changing to delivered dependent on the recipient acknowledging them?',
#  'How can you use Site Catalyst to tag & track metrics for browser extensions?',
#  'How was the Java programming language created?',
#  'What is the relationship between Clarendon Press and Oxford University Press?',
#  'How many stamps do you need to send a letter from the U.S. to Europe?',
#  'Is Barack Obama truly a bad president?',
#  'How do I sell products online with no money?',
#  'What is the chemical formula of Iodized salt?',
#  "What bike will be suitable for a guy of low height (5'2'') and low weight (45 kg) in India?",
#  'What are the 42 laws of cricket?',
#  'When is surge pricing on Uber generally in effect in Detroit and how high does it go?',
#  'What should I do to overcome my anger?',
#  'Are gay white guys interested in gay Asian guys? Why or why not?',
#  'What is one of the best short stories?',
#  'What is it like to have an uncircumcised frenulum?',
#  'What is the smell in the air right after a rain?',
#  'Will Modi become the Prime Minister of India once again in 2019?',
#  'How can I select which labels are synced from Gmail to Mail.app?',
#  'What are enterprise email solutions?',
#  'What are good examples of solutions that are good candidates for Micro Services architecture?',
#  'What’s the best way to deal with a person who always answer questions with a long unnecessary explanation?',
#  'What is the best way to gain confidence?',
#  "Who's the most important person that you should have to follow on Quora?",
#  'Where is the Royal Enfield Service Center in Satna city?',
#  'Why is there so much intolerance towards Muslims online?',
#  'Does CWA have scope equal to CA?',
#  'Which is the best web designing services in Hyderabad?',
#  'How do I find Best SEO Company in Delhi?',
#  'What are the most asked questions on the Internet?',
#  'Where can I read Indian magazines online for free?',
#  "What is Kabam's revenue?",
#  'What does the message "With delivery courier" from DHL mean?',
#  'Which is the best movie from 2016?',
#  'Does our mind control our emotions?',
#  'Is Yamaha R3 worth it for commuting everyday?',
#  'Where did the phrase "to pop a cherry" originate from?',
#  'How can I best prepare for a divorce?',
#  'Will I improve my memory power?',
#  'Will there always be web hosting that supports PHP?',
#  'Are the famous programming languages like C, C++, C# still powerful or there are other unkonwm programming languages are more powerful?',
#  'What is difference between computer science engineering and information technology?',
#  'The Indian government is banning the Rs. 500 & Rs. 1000 notes but it is coming up with the Rs. 2000 note. Will it not cause a generation of black money in the future?',
#  'What is the difference between synchronous and asynchronous communication?',
#  'What purpose do you find in life?',
#  'How can I sex chat my boyfriend?',
#  'Can a website identify you using device id or mac address?',
#  'Can I attend a Quora meetup anonymously?',
#  'Will Asian elephants always re-emerge through time in different universes?',
#  'Why do my balls itch?',
#  'How do I write more details in a Quora question?',
#  'How can I loose weight naturally without doing exercise?',
#  'Are all torrent sites blocked?',
#  'What is the difference between the current taxation and the new goods and services tax (GST) in India? What is the impact?',
#  'Which is the best book of bridge design?',
#  "Do some people have more than one potential 'soulmate' or lifetime partner?",
#  'How do i get serious about my life?',
#  'Can I recover iMessages if I deleted them (used right click delete) and then emptied my trash can?',
#  'My most favorite cousin marriage is coming and Lahore is well known for best shopping zones from where can i do the best shopping?',
#  'Which are the best movies ever?',
#  'What is your favorite board game?',
#  'Do you believe there is life after death?',
#  'How much data does the average Netflix subscriber consume?',
#  'How do I get rid of rats?',
#  "How can you prove the Abrahamic God doesn't exist?",
#  'What one thing you do in a day to keep yourself motivated?',
#  'How reliable is Storenvy?',
#  'What is a good solar panel installation provider in Merced, California CA?',
#  'Who are the first europeans?',
#  'What were the major effects of the cambodia earthquake, and how do these effects compare to the Mexico earthquake in 1787?',
#  'How do I get my birth certificate?',
#  'Ms. Clinton: How will you pull back from the hawkish foreign policy of the last 15 years? Or will your administration maintain this level of violence?',
#  'How is the speed of light different in glass and water?',
#  'What are the greatest melancholic piano pieces?',
#  'Why should I jailbreak my iPhone 4?',
#  'What is pile chipping?',
#  'Does an RAC ticket get cleared when the chart is prepared or before only?',
#  'What are simple open source Android apps from GitHub to learn Android programming by using Xamarin and visual studio?',
#  'Would you have wanted Bernie Sanders to be the President?',
#  'What are some good ways to remember how to write Chinese characters?',
#  "What is a software engineering internship at Google's Irvine campus like?",
#  'Coworking in Bangalore?',
#  'What are the requisites to decide the banks financial position?',
#  'Why does one re-read a book?',
#  'Where is a good place to mug people?',
#  'What the difference between nginx and haprox?',
#  'How does one enter the presence of God?',
#  'What are some of the science errors in the martian?',
#  'How long should international bank transfers take by SWIFT?',
#  'What is one incident of your life which you want to share with all?',
#  'How can you tell if the person is developing feelings in a "friends with benefits" arrangement?',
#  'Does the BMW connected iDrive web browser support W3C Geo-Location?',
#  'Why has there never been a black pope? How do African people feel about this?',
#  'Why is oxygen in chemical equations written as O2, when the element itself is just O?',
#  'How will the ban on Rs 500 and 1000 notes impact the Indian economy?',
#  'Can someone provide a gigantic family tree from Adam and Eve to Jesus to 2016?',
#  'Should triple talaq be abolished?',
#  'How can I improve my English in all aspects?',
#  'What is the difference between CVT, VVT and VTEC?',
#  'What color shoes go great with a navy blue dress?',
#  "Who is Batman's greatest love?",
#  'Which brand has the better build quality for their smartphone, Xiaomi, Lenovo, Huawei, or OnePlus?',
#  'Is there any app which can tell you what a person has saved your name in their contact list?',
#  'Why do emergency services sirens have to be so loud?',
#  'Is there a chance for anyone on Quora to have 1 billion views or more than that?',
#  'Which one is better for weight reducing, black tea or green tea? Do any of these improve our shade of the face?',
#  'How is delphi good for fresher?',
#  'I accidentally pushed a q-tip too far in my ear. When I pulled it out my ear started bleeding. Is this serious enough to visit the ER?',
#  'How could I improve my writing skill?',
#  'How do I become friends with a writer?',
#  'What are examples of herbivorous animals?',
#  'What are the best English books?',
#  'Is it possible for the Milky Way collide with the Andromeda? Is that process about to start?',
#  'What are some ways to improve performance management systems?',
#  'What would be a good topic for my biology IA?',
#  'Which books are best for preparation of GATE for ME?',
#  'How do I get summer internship at wipro?',
#  'How do you mash potatoes without a masher? What else can be used?',
#  'What is the best book or book series you ever read and why?',
#  'How can Apple products get a virus?',
#  'Is the digital locker launched by the government of India reliable? Is it safe?',
#  'What are some ways to position yourself as a professional in your field?',
#  'What are examples of narrative films that successfully utilize voice-over narration? Why is voice-over narration so tricky for filmmakers/screenwriters?',
#  'How should be work at iocl?',
#  'What is the best Stock trading platform?',
#  "How do France's economic activities compare and contrast to those of Colombia?",
#  'What are some preppy LL Bean boots?',
#  'How is work at Erwin hyderabad?',
#  'What are some great free iPhone apps?',
#  'Indian Railways: Why charging points in Indian railways operate on 110 Volt Direct Current (DC)?',
#  'What were the circumstances of your first lesbian experience?',
#  "How's Australia for software testing jobs? What is the sense of security?",
#  'How does it feel to have a nerd girlfriend?',
#  'If you feel unsafe stopping for a police officer on a deserted road while driving alone, is it legal to keep driving until you get to a safer place?',
#  'How do I jtag xbox 360?',
#  'What are some examples of pluralistic societies?',
#  'What was the best day of your life so far?',
#  'What is an allergy shot?',
#  'Is Leo Gura’s Actualized.org a scam?',
#  'Since more and more dark energy appears does this mean that it is infinite or that the potential dark energy that can be created is infinite?',
#  'How should one start learning Python programming for electronics applications?',
#  "What's the best programmnig language for begginers?",
#  'What are some great suggestions to gift my girlfriend for her birthday?',
#  'What is the best way to make extra money?',
#  'Where can I buy polymer clay in the Philippines?',
#  'How can l get a girlfriend?',
#  'How is Sundar Pichai perceived internally at Google?',
#  'What does the title "Winter\'s Bone" mean?',
#  "Is education in countries with teacher's unions better?",
#  'What is the best way to learn piano for adult?',
#  'What troops should be made to get loot in town hall 9?',
#  'Which are steps to be followed for a seat in Stanford University - Stanford Graduate School of Business with a financial aid from India?',
#  "Why do I sometimes feel an electrical spark when my skin touches someone else's skin?",
#  'Where do private military contractors get their weapons from?',
#  'What is climate change and why is it important?',
#  'What is the scope of industrial engineering in the word?',
#  'Who is the number 1 hero in Tollywood?',
#  'What is the best way to implement enums in Python?',
#  'How can I boost my immune system?',
#  'How do I break up with him?',
#  'What is the most important thing in our life?',
#  'How do I gain confidence in life?',
#  'How many times does blood circuit through our body per day?',
#  'I am doing diploma from computer science what are the points I should follow and remember to attain a good career, any suggestion from experienced one?',
#  'How do I delete my Zoosk account?',
#  'If you dream about something that happened to you in the past and relates to your situation now could the dream come true?',
#  'If NASA found out, halfway through the STS-107 mission, that the shuttle is damaged, what could it have done to save the crew?',
#  'What would happen if China and the United States went to war?',
#  'When is Yom Kippur?',
#  'Which mobile has best camera?',
#  "What was Albert Camus' greatest writing?",
#  'Is it wrong to eavesdrop?',
#  'What happens after the lifetime of a black hole ends?',
#  "If someday a habitable earth-like planet was found, who can decide how it's going to be named?",
#  'How did the US allow China to become a significant power and challenge its superpower status?',
#  'What are the differences between romanticism and neoclassicism?',
#  'Will my computer die if I update to Windows 10?',
#  'What is that one song you recommend me listening right now?',
#  'How did trump become president?',
#  'Why was my question marked as "needs improvement?"',
#  'Did Captain Kirks crew cower in their cubicles while the Enterprise battled space people?',
#  'What places should I visit during my visit to Kerala during July?',
#  'What pastries can you use for pies?',
#  'What is gain margin, phase margin, gain crossover frequency, and phase cross frequency? What is the practical use of these parameters?',
#  'How can the BJP justify wasting 3600 crore of the taxpayer’s money on a statue of Shivaji?',
#  'How do I know who is following me on Snapchat?',
#  'What is the process to determine the density of aluminum and how does tin compare?',
#  'How do I search job in Dubai?',
#  "What's your New Year 2017 resolution?",
#  'How do I get over oppression at work?',
#  'What is a good present to get your Dad for Christmas?',
#  'How much time will it take to complete a BCG at IBM?',
#  'What was the best day of your life?',
#  'Yamaha F310 or FS100C, Which is better?',
#  'What should be done to get rid of laziness?',
#  'How do avalanche beacons work in case of an emergency?',
#  'Do females find the scent of male sweat attractive?',
#  'What is the metaphase in mitosis and meiosis?',
#  'Is www.globaltestmarket.com a legit site? Why or why not?',
#  'What is best career plan after completing graduation in b.tech (mechanical engineering)?',
#  'Is there a way to see who viewed my Instagram page?',
#  'Which books should I prepare to crack IIT JAM in Biological Sciences?',
#  'What should one consider when looking to buy a walkie-talkie (two-way radio) system for business use?',
#  'Why nobody replies to my questions on Quora?',
#  'How can I consult a good free online astrologer?',
#  'What are some best techniques or exercises to increase my brain power?',
#  'Who are all the actors who played Batman, in order?',
#  'What is the most viewed answer you have got on Quora?',
#  'What happened after the Mahabharat war?',
#  'What are some things new employees should know going into their first day at Balchem?',
#  'I hear conflicting evidence that Prozac causes weight loss and weight gain. Which is it?',
#  'Why do you believe the earth is flat?',
#  'Is AIB (All India Bakchod) overrated?',
#  'When will the planet start cooling again?',
#  'What should I eat to gain weight?',
#  'Are there Best Buys in China?',
#  'I filled the wrong AADHAR enrollment number in the online JEE main form and now it is not letting me edit it. What should I do?',
#  'What is the best tutorial for Puppet or Chef?',
#  'When a man becomes a President, his wife is called first lady. If a woman is President, what is her husband called?',
#  'How will Brexit impact the flow of goods and people between Northern Ireland and the Republic of Ireland?',
#  'What causes nodules on your thyroid?',
#  'How do I get started for cds exam 2016?',
#  'What does Turkish sound like to you?',
#  'What does the classical paradigm mean?',
#  'How do I convince a lady to have sex with me?',
#  'What is the easiest and simplest proof of the chain rule?',
#  "What's the first thing you should tell a 911 operator?",
#  'How cool were you in high school?',
#  "What is a goood answer to 'Why should I not hire you?'",
#  "What are the exact reasons behind trending of 'CYRUS FOR GOVERNANCE' on Twitter/web ?",
#  'Which is the best traveler website?',
#  'How would Trump presidency affect Indian students in the US?',
#  'What are the best Add-On items for Amazon?',
#  'How do I find out if I have been blocked on LINE?',
#  'Why is the Salton Sea so important?',
#  'How does a girl feel losing her virginity to her lover?',
#  'How do I make a manual light switch?',
#  'I want to do an internship at NALCO . What kind of projects are available at NALCO?',
#  'What are the pros and cons of Linux Mint vs Ubuntu?',
#  'Where do I start in order to succeed in life?',
#  'Is there a better way to remove Google 2-Step verification process?',
#  'What is The Importance of Having an Education.?',
#  'What are the healthiest breeds of cat?',
#  'Do atoms rotate?',
#  'What is the work of hr in any company?',
#  'To what extent do NGOs involve in illegal activities?',
#  'Which is a real YouTube video downloader?',
#  'How can I design my website?',
#  'Do you like using Quora?',
#  'What do you do during weekends?',
#  'Was Jesus Jewish?',
#  'What are all the flavors of Native American Spirit Cigarettes, and what do the colors mean?',
#  'What are some ways by which a student can earn money in college?',
#  'How do I get all the list registered to your gmail account?',
#  'How can I lose my weight in two weeks?',
#  'What are the best ways to earn money while studying in countries like India?',
#  'Why is Wikipedia so anti white people?',
#  'Why do we have dreams and usually forget them the next morning?',
#  'Which is best gaming laptop under 60000?',
#  'What are some ways of removing blackheads on thighs?',
#  'What is the best way to improve reading comprehension skill?',
#  'What is the fees of SAP Course in India?',
#  'If estimated, how much horsepower does the average human have?',
#  'What are some effective study and exam-testing habits or tricks that you would recommend?',
#  'What equipment is needed to do P90X?',
#  'What is the role of artificial Intelligence in future technology?',
#  'What do South Indian guys think about North Indian girls?',
#  "What does it mean when imessage doesn't say delivered?",
#  'How do I learn to say no?',
#  'Which is the best smartphone I can buy under 15000 in july 2016?',
#  'What is the difference between topoisomerase 2 and topoisomerase 4?',
#  'How much are the below domains worth? 888X4.com,C2PIR.com,CIBERLOVE.com,WALKOFFFAT.com,CYCRIME.com,IAI8.com,ITGENY.com,PRISONLOVERS.com,GONE2GOD.com',
#  'Does GPA matter more than test scores for college admissions?',
#  "What is the climate of California's coastal regions, and how does it compare to the climate in Connecticut?",
#  'What is the best way to find someone?',
#  'What are the days of the week based on?',
#  'What is morphine sulfate?',
#  'Can your personality change?',
#  'How do I score 600+ in NEET Phase 2 within 2 months?',
#  'What is the best way to restore a Dell Inspiron 530 to factory settings?',
#  "What does Germany look like, and how does its geography compare to Norway's?",
#  'Can I use my laptop as a monitor? If so, how?',
#  'What is unique about Kerala which stands out from other states?',
#  'What is the most erotic short story?',
#  'Are all the nations of the world descended from the twelve Israelite tribes?',
#  'What is the background and setting of the tiger in the tunnel by Ruskin Bond?',
#  'What are news agencies?',
#  'Why do you wear clothes?',
#  'How can I find what I love?',
#  "What's it like to work at Google as a contractor?",
#  'Do long distance relationships work?',
#  "How can I find someone's WhatsApp account number by his Google account?",
#  'What are the best website builders in India?',
#  'How do I get the call details of another phone number?',
#  'Is Gulab Jamun called Rasagullah in UP?',
#  'Where can I get the Olympiad question papers?',
#  'What was the Petrine Doctrine? How was it suceded?',
#  'Who are the best fashion social media agencies in Australia?',
#  'What are the best option after completing my B.Tech in mechanical engineering?',
#  'How can I restore my factory settings to my Dell 3521 laptop?',
#  'What percentage of Uber does Jeff Bezos own?',
#  'Why are so many Tamilians supporting Jallikattu ?',
#  'Can I build a website on my own?',
#  'What would a good data scientist teacher look like?',
#  'Can you see who viewed your Instagram?',
#  'Why can a database table have only one primary key?',
#  'Why do we age slower when traveling at or near the speed of light in space?',
#  'Are food allergies more common in USA?',
#  'Which are the best ways to lose weight?',
#  'How do I solve 2^(2x)+3•(2^x)-10=0?',
#  'What is the best way to learn and master a computer programming language?',
#  'What is the difference between Indian army and BSF?',
#  'I learned neutrons of H2 atoms can be taken away by adding photons. Can we do the same for other elements, oxygen atom for instance?',
#  'How do I unlock disabled iPhone 6 with no itunes?',
#  'Where can I get best support in Sydney for buying a property?',
#  'Do Quora search engines work on PyPy?',
#  'What is your biggest flaw?',
#  'How do science and engineering PhD programs differ?',
#  'If the Arab societies believe the 1919/1920 borders of the Arab states are illegitimate, do they also believe the Arab states should be dissolved?',
#  'Whether extension of CA-articleship is to be served at same firm/company?',
#  'How can I start a conversation in international students group?',
#  "Why doesn't India have a uniform civil code?",
#  'Why is AngularJS called like that?',
#  'What is a six-pointed star symbolic of?',
#  'What hotel in Bhilai would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?',
#  'What were the main and most important political causes of World War 1?',
#  'When wild humans are found in the wild, why are people using the word "rescue" from his/her animal families when they\'re actually kidnapping him/her?',
#  'What are some ways to start a business?',
#  'Is it possible to love more than one person at a time?',
#  'How good was the surgical strike by Indian Army on terror camps at PoK?',
#  'Are wearing shoes good for your feet for running?',
#  'What are some interesting pictures?',
#  'Is transgender a mental illness?',
#  'How could I adjust the font size in the Quora?',
#  'Are there any examples who struggled in the beginning of their career despite of a good academic record and later achieved a good professional satisfaction?',
#  'Which is the best online shopping site for sarees in India?',
#  'How can I access blocked Torrent Sites from Chrome?',
#  'Is sodium carbonate soluble in hydrochloric acid?',
#  'What is the maximum quantity of food that a single person can consume in a day?',
#  'How can I read Monocle magazine without having to pay for it/subscribe?',
#  'How do I know am not been cheated on by my partner in a relationship?',
#  'Is a college degree worth it?',
#  'My son plays Minecraft on the computer. The other day he was playing online and someone asked him "d or t." What does this mean?',
#  'How can I apply for private medical colleges of MP ? I do not have MP domicile.',
#  'What are the biggest lies you told in school?',
#  'What are monetary benefits in GE India above CTC?',
#  'Which is the best way to learn English literature?',
#  'How do I post something on Quora?',
#  'How do you open a JSON file?',
#  'How should I start a mobile marketing and mobile commerce business?',
#  'What is property?',
#  'What happened after the Kurukshetra war?',
#  'Why should one vote for Hillary Clinton in the 2016 presidential election?',
#  'What are some examples of the different types of sailboats?',
#  'Why is Donald Trump not racist?',
#  'Has anyone got MIUI 8 update for Xiaomi Redmi Note 3?',
#  'What should I do for improve my IQ level?',
#  'What is a list of important derivations of physics class 11 CBSE?',
#  'What is the difference between active and passive devices?',
#  'What is the shortcut key of subscript and superscript in Excel?',
#  'If someone has to transfer money from a BofA account to a Chase account, how much would the bank charge for the transfer?',
#  'What did John Maynard Keynes do during the Great Depression?',
#  "I have no desire to do anything. I don't enjoy my life at all. I am not depressed, but I just don't want to do anything. What do I do to regain myself?",
#  'How did caste system started in India?',
#  'What is the difference between story and script of a film?',
#  'What is the safe and best investment?',
#  'How does stock market work?',
#  'Why and how do oceanic trenches form?',
#  'ANAL sex IS PAINFUL?',
#  'Does Jill Stein have a chance of becoming elected?',
#  'What are the other ways of saying "we hope you understand that"?',
#  'What are some of the best resources online to learn German?',
#  'Why do you think people become entrepreneurs?',
#  'What is the best subject line for wedding invitation email?',
#  'Why does the Chinese company "Alibaba.com" have a name from the Arabian Nights?',
#  'Which is the best institute for GMAT preparations in Delhi?',
#  'What is the average and highest package of Galgotia University Noida?',
#  'Why is naming things hard in computer science, and how can it can be made easier?',
#  'How will the world be in 50 years?',
#  'What are the ideal growth stocks to invest in right now?',
#  'Why is Saurav Ganguly considered the best cricketer to have captained India?',
#  'Is President Obama right in allowing young illegal immigrants to work in America?',
#  'What is the next number in the sequence: 1, 2, 3, 4?',
#  'What are some messy updos for long hair?',
#  "What's the tax rates for someones who works in Brussels at the European Commission (they are independent so they don't use the Belgium system)?",
#  'What is the concept of Zakat in Islam?',
#  'How do you get a girl to like you?',
#  'What are some examples of EM waves?',
#  'What laptop should I buy to play GTA 5?',
#  'Which one do you think is better to learn in 2017, Scala/Play or Elixir/Phoenix?',
#  'How open and less conservative is Jordan?',
#  'What is the best way to make someone forgive you?',
#  'Which small business can start in UAE?',
#  'What is the difference between smoking weed and hash?',
#  'Can I use a Bluetooth 4.0 device on my Bluetooth 3.0 Android smartphone?',
#  "Which woman has world's biggest belly button?",
#  'Where do I get the pdf of the text - insight to chemical engineering by subbu?',
#  'What\'s another word for "word"?',
#  'How does hydrochloric acid act as a catalyst when brought into the iodine clock reaction?',
#  'What do teenagers do that other teenagers find cringeworthy?',
#  'How do I crack CLAT ?',
#  'Have you ever visited Switzerland?',
#  'Why is the Republician Party known as the GOP?',
#  'Where do I find a simple to understand solution on how to lose weight?',
#  'If Hillary Clinton is elected which industries would do well which ones would suffer?',
#  'What is the average cost per response for a survey?',
#  'Why do some people want to have sex on every occasion and moment?',
#  'What are best websites to watch Marathi movies?',
#  'How much does the Indian government have to pay to the World Bank and IMF each year as interest on the loans India has taken?',
#  'How many medals have Indian athletes won in Olympics till now?',
#  'How is the scope of turbomachinery design in India?',
#  'How can someone get more Facebook friends?',
#  "If I'm on section 8 with my mother could I get a transfer for an apartment for my own self?",
#  'How do I get more traffic on my website?',
#  'What would happen if the American public took arms against the government?',
#  'How would you scrub through data?',
#  'Why does Malibu rum go bad?',
#  "Can Martin O'Malley win?",
#  'What are some of most interesting and unknown facts about Shah Rukh Khan?',
#  'How many ways to enjoy life?',
#  "Sir if pnb banks are rejected my loan and give to fall's reason than how can I gate the loan?",
#  'Are teeth whitening products (such as the brand Carbon Coco) safe products to use?',
#  'Where can I watch and download Hong Kong dramas for free, without ads?',
#  'What are the best earphones under 1000Rs?',
#  'What are the benefits of not taking any casual leaves in PSUs like Coal India Limited?',
#  'Who is best physics teacher for IIT JEE in Kakadev Kanpur?',
#  "In which field I should make a career, Aerospace or Aeronautics? As I'm very interested in technology and aim to be TECHPRENEUR.?",
#  'Can I make over 100 million dollars selling on amazon? Be honest with me because if jeff Bezos can do it, I can do it too?',
#  'What is the best way to find the products of any chemical reaction?',
#  'Can you see who views your Instagram?',
#  'How is “this” used in a sentence?',
#  'How do I make peace with the fact that nothing in life is promised to me?',
#  'What if a girl who likes me suddenly ignores me? What does it mean?',
#  'How can I take dog by train?',
#  'Who gets the profit from the Ryder Cup?',
#  'How did Donald Trump win the presidency?',
#  'What is the difference between a customer and consumer?',
#  'Is Allen Career Institute Jayanagar (Bengaluru) good for Neet 2017 repeaters batch?',
#  'Are girls intimidated by attractive guys?',
#  'What is the secret behind the Vitruvian Man diagram painted by Leonardo da Vinci?',
#  'How can one get over a fear of flying?',
#  'If you could change any one thing from your past, what would it be?',
#  'What are the best Mac tips for Windows users?',
#  "Why doesn't anyone text me?",
#  'What is the best language for web development?',
#  'How one should get prepared for campus placement?',
#  'What the purpose of life on earth?',
#  'Which actress pierced her navel?',
#  'What do I need to start my own cafe?',
#  'Why do runners die during marathons?',
#  'What is the disadvantage of demonetization of Indian currency?',
#  'How do I master C-Programming?',
#  "How is Valentine's Day celebrated in Germany?",
#  'Where can I get level 2 CFA June 2016 scheweser books in pdf format?',
#  'How can I get rid of the Ransom Virus ?',
#  'What songs make you cry?',
#  'How can we improve our personality?',
#  'What are the symptoms of autism?',
#  "How do I develop my fourteen years old son's personality?",
#  'What is the longest time you had to do push ups at boot camp?',
#  'Why heart works after death?',
#  'What are the best ways to handle bullies?',
#  'What are the top science consulting firms in San Francisco?',
#  'Can you help me get a lot more followers on Instagram?',
#  'How did you make friends on Quora?',
#  'Why n! =n.(n-1).(n-2)...and so on?',
#  'How do I get into the Merchant Navy?',
#  'Why is online marketing important?',
#  'How can I reduce my belly fat through a diet?',
#  'What was your favorite movie of the 1980s?',
#  'How does dating in the UK differ from dating in the US?',
#  'Why does time feel like it goes faster as we get older?',
#  'What/ Is there a difference between "I have read many stories." and "I had read many stories."?',
#  'Why was screenshot feature created?',
#  'Who do you think is the most irritating character in Game of Thrones?',
#  "I've been eating about 500 calories a day for years but don't get hungry. How can I make myself get hungrier/make eating easier?",
#  'How many people a year in the US die before age 40 (or whatever other young age)?',
#  'Can a 17 year old green card resident be alone for 2 weeks with its US citizen step dad?',
#  'Why should I choose UT Dallas over Northeastern University for MS in CS?',
#  'Where is hell in India?',
#  'What is an excellent brand of multivitamin?',
#  'What is the blood group of a mosquito?',
#  'If universe is expanding without a limit and dark and vacuum energy are created as it expands?',
#  'I enjoy performing oral sex on my girlfriend, but she always gets wet too quickly. After that, liquid comes from her vagina, causing her vagina to have a strong smell and a salty taste. What should I do?',
#  'What are benefits of green coffee?',
#  "What is the reason behind government's ban on 500 & 1000 rupee notes? What are the immediate effects and how useful will it be in curbing black money?",
#  'Has Hillary Clinton lost her law practice license? If yes, why?',
#  'What happens to me if I die?',
#  'Why is Saltwater taffy candy imported in Czech Republic?',
#  'What are the unspoken rules of sex?',
#  'Why do people ask stupid questions on Quora that could be easily answered by Google?',
#  'How can I build my own laptop at home?',
#  'What food do mountaineers eat during their expeditions and ascents?',
#  'Who is the most famous blogger you follow?',
#  'Which is your absolute favorite quote?',
#  'What kind of programming language should I learn if I want to debug a game-making website like Zondle.com?',
#  'Have you ever seen a student roast a mean teacher?',
#  'What is the difference between the Semiotics of Saussure and Peirce?',
#  'How do mushrooms grow?',
#  'How can I showcase my networking skills during scholarship/job interview?',
#  'How do I prepare for the Cisco 500-201 exam?',
#  '"What has passed is past" vs "What passed is past", which one is correct?',
#  'Did you regret waiting until marriage to have sex?',
#  'Should I wait for the release of the new Macbook Pro (August 2016) or buy one now?',
#  'How can I convince someone over something?',
#  'What is the limit as x approaches 0 of (sinx^2) /x?',
#  'What is your review of Sony India?',
#  'How do I slim down my thighs, calves and buttocks?What workouts should I do to achieve it?',
#  'Should I worry if my period is a day late?',
#  'Can you get pregnant before ever getting your first period?',
#  'What are dreams and why do we have them?',
#  'Why do football players wear rubber bands around their biceps?',
#  'What is the best hosted e-commerce platform?',
#  "Why don't you believe in aliens and why?",
#  'How can you cure sulfur burps?',
#  'Which are some of the best school campuses in India?',
#  'Are applications that allow me to download songs free such as GTunes Music legal?',
#  'Why Arnab Goswami resign times now? And start entrepreneurs.?',
#  'What are the best activities to do with children when visiting Matsue, Japan?',
#  'For you, what are the top 5 most entertaining motorsports?',
#  'Who invented the glass?',
#  'Do Tamil Nadu people want freedom from India or are they happy with being a part of India?',
#  'What is the need of power factor?',
#  'What should I search in Quora?',
#  'Why does the truth tend to hurt?',
#  'Height relaxation for SC candidate in cpo?',
#  "Why doesn't my saliva quench my thirst?",
#  'Is it worth subscribing to Amazon Kindle Unlimited in India?',
#  'I am B.Tech Computer Science graduate, looking for job. Does any one know about good opportunities around Gurgaon location currently?',
#  'How can I identify a person on a picture?',
#  'Which university is the best for computer engineering in the world?',
#  'What is the best place to take photographs of New York City?',
#  'Should Quora show you a notification when someone downvotes one of your answers?',
#  'I am 18 and just inherited 100 million dollars, what should I do with it?',
#  'What is the bad thing about quora?',
#  'You need to kill someone, but you have to send them at least one text message before you kill them. What do you send?',
#  'Will President Obama declare martial law and remain in power if Trump is elected?',
#  'What would be the best day of your life?',
#  'Do women enjoy one night stands?',
#  'What are the questions asked in power grid India interview?',
#  'What are some tips on making it through the job interview process at WABCO?',
#  'Should I evolve or power up my Pokémon first in Pokémon GO?',
#  'What is the use of coriander?',
#  'If it is 12 noon at Greenwich, calculate the local time of the places located on the following longitudes: 69°E, 30°W and 12°E?',
#  'What are some good psychological hacks?',
#  'Are there enough jobs for everyone in the world?',
#  'What is the best way to round to the nearest integer?',
#  'Why is love so important in human life?',
#  'What are good ways increase page rank in Google search engine with SEO?',
#  'How do I control my spending?',
#  'Which is best leather strap cutter machine?',
#  'How do I build a profile to get accepted into a star college like Caltech, MIT, Stanford or Berkeley for an MS in aerospace engineering?',
#  'What is the best budget hotels in Udaipur for accommodation of me and my friends in this coming New Year eve?',
#  'What is the story behind the ancient Dudhadhari Temple of Raipur?',
#  'What is the best smartphone to date?',
#  'Why does Scarlett Kennedy enjoy using manipulation?',
#  "Why do USA people speak so loud even though you're close to them?",
#  'Which is the best mobile service (With data) in Bangalore?',
#  "What does the '100' emoji generally mean?",
#  "Which is the best VPN to get for free, which can bypass my college's cyber security?",
#  "What's the business model of OLX?",
#  'Should I disable Windows Defender to be more anonymous?',
#  'What are some interview questions being asked by a fresher of civil engineering?',
#  'What is the biggest regret you have?',
#  'What programming language should I learn if I want to do a 2D MMORPG game?',
#  'Which is a good solar panel installation provider near Ione, California CA?',
#  'What was the most embarrassing moment in front of your cousin?',
#  'What are the best b-schools for finance?',
#  'What hotel in Jabalpur would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?',
#  'What does Amazon do if you receive your Prime package late?',
#  'What are the best sites to watch Bollywood movies for free?',
#  'What is the career path for Marketing officer scale 1 through IBPS?',
#  'Should I carry my blood group card with me or will they test my blood anyway?',
#  'Can I change jobs 6 months after I-140 approval (first step for a green card)?',
#  'How do I recover my WhatsApp chat and images after three months of deletion?',
#  "What is a typical Indian's worst habit?",
#  '1800^~^251^~~^4919@! ^! @ ESET Antivirus Tech Support Number?',
#  'Could someone list out some good girls PG in Indira Nagar?',
#  'How did military tactics work during the Seven Years War and Napoleonic Wars?',
#  'How can you describe the process of natural selection?',
#  'What should I do after retirement?',
#  'Who will win the 2016 Super Bowl?',
#  'What are some nerdy pick up lines?',
#  'Is it illegal to follow a celebrity for a long period of time?',
#  'How can I track Phone Number?',
#  "What's the strangest request you've had at McDonald’s?",
#  'What kind of hair styling machines to take on a destination wedding?',
#  'How can I find the pH of a solution of NaHCO3?',
#  'Do soldiers collect their shell casings after a firefight?',
#  'What are your favorite books?',
#  'How does Google\'s "No CAPTCHA reCAPTCHA" work?',
#  "Whom should I ask for the best solutions to QuickBooks' technical issues?",
#  'What is the best book to read to learn Java?',
#  'Why can\'t I see all the "likes" on a person\'s Facebook status?',
#  'How do you give a fuck?',
#  "Was Karen Allen annoyed she wasn't asked back for the second Indiana Jones film?",
#  'How do I personal message someone on Quora?',
#  'How will the ban on Rs 500 and 1000 notes impact the Indian economy?',
#  'How do the types of slow dances originate?',
#  'What are the best side dishes for pork chops?',
#  'How can a Jew not believe in Jesus but still not be an atheist?',
#  'Are actresses given days off during their menstruation periods? How do they continue to perform through out a month?',
#  'Are there any free and somewhat accurate IQ or psychometric evaluations available online?',
#  'Some people think global warming can cause colder winters. How is that possible?',
#  'Based on what he says, do you respect Donald Trump?',
#  "What's meaning of cassion?",
#  "How's is working environment in price water house coopers?",
#  'What is the corporate culture like at Brady? How is the culture different than other companies?',
#  'What are the uses of turmeric powder?',
#  'What is corporate accountability?',
#  'How are radio waves emitted?',
#  'Should smoking be banned?',
#  "Plz suggest me how can I get someone's call history?",
#  'What is the best intelligence agency?',
#  'What are blowers and compressors used for?',
#  "How do I really speed READ? I Saw YouTube tutorials didn't help, any real video out there?",
#  'What is green IT?',
#  "How would I dress like it's the year 1990 if I'm a guy?",
#  'What universities does NN recruit new grads from? What majors are they looking for?',
#  'What is your absolute favourite romance anime?',
#  'How high should cycling shorts go?',
#  'What is the main and most important role of government in society?',
#  "Who has the most beautiful natural boobs you've ever seen?",
#  "What are the AAP Government's biggest achievements in Delhi till December 2016?",
#  'What developments have taken place in Varanasi Loksabha constituency after Modi has won this seat?',
#  'Where should I visit in Ho Chi Minh City?',
#  'What is the best way to measure hertz?',
#  'Why is POP3 Port 110 offered if it is not recommended?',
#  'Why are people still talking about this gorialla named harambe billionaires must be laughing their ass off at our priorties and focus/attention?',
#  "How would you answer this job interview question: Why shouldn't I hire you?",
#  "What can be done about a neighbor's barking dog who's away at work?",
#  'Is there any English to German club on Duolingo that I can join?',
#  'What are lessons you learned in 2015?',
#  'If Donald Trump were to withdraw from the US election, how would this affect the entire election process?',
#  'What is Linus Torvalds like to work for?',
#  'What is passivity?',
#  'What are some of the most badass urdu poems ever?',
#  'Which algorithm is Cubeduel using for duel matchmaking?',
#  'What motivated you to get into civils and what motivates you to work sincerely?',
#  'What is pulsating magnetic fields?',
#  'How can I teach myself machine learning?',
#  'How does it feel like for an Indian living in France?',
#  'Who are the top Vedic astrologers in India?',
#  'Difference between HRM and International HRm?',
#  'What makes for great sex?',
#  'What is the funniest thing you have ever done or seen someone to do?',
#  'What are the best free gay porn tubes?',
#  'Are stay at home wives better as wives than working wives?',
#  'How can I store 1TB of data online for free?',
#  'What is the English translation of لجنة امتحان?',
#  'How can you increase your height?',
#  'Can the iCloud lock be broken?',
#  'Were the doping charges against Diego Maradona in the 1994 World Cup genuine or fabricated to oust him?',
#  'My mobile was stolen. Is it possible for the thief to change its IMEI number by using any software?',
#  'How much cost is required to take a franchise of PVR?',
#  "How are careers in botany changing and what's necessary to stay current?",
#  'Is Donald Trump really a racist?',
#  'Why do some humans have allergic reactions to cats? What is the science behind cat allergies?',
#  'How much art is sold online?',
#  'How much money does a Ranji Trophy cricketer earn?',
#  'How do I buy shares?',
#  'What is the two - gap model in development economics?',
#  'Why is the video quality on Android Snapchat so much worse than iOS Snapchat?',
#  'How can I become rich?',
#  'What are some servo motor mechanisms?',
#  'How can I start an investing company in which investments are directed to oil and gas growing companies?',
#  'What are the main organs involved in the circulatory system of bivalvia?',
#  'Do we need smaller states?',
#  'Which is the best course for digital marketing?',
#  'What are the legal problems with digital signature?',
#  'What were the major effects of the cambodia earthquake, and how do these effects compare to the Somatra earthquakes in 2007?',
#  'Has it ever happened to you that you were studying and a part of the topic got you sad to tears?',
#  'How do I improve my French pronunciations?',
#  'How should India respond to uri attacks?',
#  'In the United States, why do women wear clothes that expose more of their bodies than men?',
#  'What are the first signs of a homosexual person turning straight or bisexual?',
#  'What are the joys of reading?',
#  'Why are brass knuckles illegal in Florida?',
#  'How can a Syrian refugee family find a sponsor to resettle to Canada?',
#  "How can we trace a phone call's origin or cellphone location?",
#  'How will the ban of Rs 500 and Rs 1000 notes affect Indian economy?',
#  'How can I create a WiFi hotspot in Windows 7?',
#  'Do medical deemed universities follow caste-based reservation policy?',
#  'Porn addiction: I want to quit watching porn and masturbate. How do I stop it and not feeling empty?',
#  'How can I get a list of my Gmail accounts?',
#  'What will happen if I only eat fruits and vegetables every day?',
#  'Is it possible to use minimax algorithm for a multiplayer game?',
#  'Where can I see my asked questions in Quora?',
#  'What is the oldest currently existing bottle of American whiskey?',
#  'What are some things new employees should know going into their first day at South Jersey?',
#  'When does a luxury become a commodity?',
#  'Is string theory total bullshit?',
#  'What are some inventions made in Ancient Rome?',
#  'In blood transfusion what is major, minor cross match and the purpose of it?',
#  'How much do I need to earn monthly to live in Shanghai, China?',
#  "Measurements: What is 'GAJ' and its equivalent in Sq Ft.?",
#  'What is it about the Iran nuclear deal that keeps them from getting nuclear weapons?',
#  'What can I say to respond "Thank you so much"?',
#  'Can a long distance relationship still exist? How can you make it work?',
#  'Will Peter Jackson make movies of The Silmarillion?',
#  'How can I go from a 2.5 GPA student to a straight-A student?',
#  'What are the best brands for Punching bags in UK?',
#  'How wikipedia earn money without ads in their website?',
#  'What is the first programming language I should learn?',
#  'What is means love?',
#  'What is the most unfortunate country in the world? Why?',
#  'How was the last night debate between Trump and Clinton?',
#  'Can anyone provide me the soft copy of sociology themes and perspective by Haralambos?',
#  'Boiling and freezing point of cereals?',
#  'How do I write a letter to the bank to close bank account?',
#  'How does it feel to have sex with a stranger?',
#  'How can I make pizza in grill microwave oven?',
#  "What is Alzheimer's disease, and what are its symptoms?",
#  'Where can I find Fatmagul with English subtitle?',
#  'Can I trust healthwarehouse.com?',
#  'How do you get cash without earning it, legally?',
#  'What are the best career options after BCOM?',
#  'How will banking and PSU Debt funds Fare after Demonetisation?',
#  'What is eyebrow threading and does it hurt?',
#  'What do you wish you knew at age 30?',
#  'What was the worst day of your life and why?',
#  'How do I get myself into a study routine?',
#  "How can I find out who's stealing my lunch from the office fridge?",
#  'Why is Meryl Streep considered by many to be one of the greatest actors?',
#  'When is the best time to take apple cider vinegar? ',
#  'How do I upload and monetize other video on YouTube?',
#  'What are some status symbols in Silicon Valley?',
#  "What are some mind-blowing iPhone/Android gadgets that most people don't know about?",
#  'What is the average bit rate of a HD video?',
#  'Why do I hardly feel any emotions?',
#  'How much one can earn from YouTube?',
#  'What is it like to work at Capgemini India?',
#  'What was the significance of the battle of Somme, and how did this battle compare and contrast to the Battle of Calabria?',
#  'How does scrapping the Rs 1000 and 500 notes help in curbing terrorism?',
#  'How can I gain weight in a healthy way?',
#  'What are the theories as to what happens after death?',
#  'How do I hack an Instagram account?',
#  'How do I stop day dreaming and mind wondering?',
#  'What is the best business school in California?',
#  'If you were president, what is the first thing you would do?',
#  "There are 8 balls. 7 of them weigh the same. 1 of them has a different weight, (you don't know if it's heavier or lighter). How do you find the odd ball with 2 weighs?",
#  'What is the best IT-recruitment agency in Amsterdam?',
#  'We breath O2 in and CO2 out. Where does the carbon atom come from?',
#  'What are the most popular technology portals in India?',
#  'What is your new year resolution for 2017 or goal for 2017?',
#  'Do I lose energy when I pass a bowel movement? (Go to the toilet for a No. 2)',
#  'What hotel in Munsiyari Hill-station would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?',
#  'How do I upgrade to Windows 8.1 from Windows 8?',
#  'Which is the best service LG refrigerator service center in Hyderabad?',
#  'What is the meaning of “shalini”?',
#  'Where is the best place to sit in a movie theater for a 3D movie?',
#  'What is the importance of water treatment for boiler feedwater?',
#  'What are the major differences between Indonesia and Malaysia?',
#  'How can I cure my hormonal acne?',
#  'Getting bored of Facebook and Twitter what to should I do?',
#  "What are some of the craziest/weirdest things you've seen a bear do?",
#  'Is it necessary to dress formally for an interview? And why?',
#  'How do I earn 5000 rupees online?',
#  'How do you know if a guy is obsessed with you?',
#  'What is the best way to control our emotions?',
#  'Why will ISPs block forum sites when we lose net neutrality?',
#  'Do you think revenge is sometimes justified?',
#  'How can I make the best of my B.tech life?',
#  'What are the alternatives to CNN for getting neutral, fact based news?',
#  'What is the best food for a 5 week old puppy?',
#  'What is the best possible way to get away with murder?',
#  'How do I start IAS preparation along with BE engineering?',
#  'Why would you buy an iPhone 7?',
#  'What is the difference between normal files & .min files?',
#  'What is the hypothesis on why Glossopteris was so widespread?',
#  "What's the fastest way to learn Japanese?",
#  'What are some great uses of imagery in rap lyrics?',
#  'Is estrogen a lipid, carbohydrates, or protein?',
#  'What is a good salary in Istanbul, Turkey?',
#  'What hotel in Araku Valley Hill-station would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?',
#  'How do I avoid paying capital gains tax? I live in Brooklyn, n.y.?',
#  'What is the entire process of becoming a certified ethical hacker?',
#  'Which Indian city has the best nightlife?',
#  'Which is better, VIT or IP University?',
#  'What is an even and odd number?',
#  'What hotel in Lambasingi Hill-station would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?',
#  'How can I deal with my emotionally abusive mother?',
#  'Will art classes teach me useful skills as a UX analyst who wants to move more towards UX design?',
#  'Is Virat Kohli 2016 better than Sachin Tendulkar 1999?',
#  'What are complex networks?',
#  'What was the most embarrassing thing that ever happened to you as an adolescent?',
#  'How can I learn web designing beginning level?',
#  'Is World War 3 closer than it has ever been?',
#  "What does 'shake' mean as regards to iPhone 4?",
#  "Why does it hurt when the person you love doesn't love you back?",
#  'What are the best ways to make your life easier?',
#  'Why do people say they are ethnically Jewish?',
#  'How can I improve my pronunciation in English?',
#  'Could Hillary Clinton actually go to jail?',
#  'Do wormhole really exist? If yes, are there any discoveries so far?',
#  "I'm a college sophomore taking 14 credits. If I can't pass all of my classes, should I drop out?",
#  'What are the best ways to learn English and speaking?',
#  'How can I get TIN no in Kerala? Am doing textile bussiness from home . Is it possible to get without office?',
#  'What should Bill Clinton be called if Hillary is elected?',
#  'Will banning Rs.500 and Rs.1000 notes help to solve black money and corruption?',
#  'How do I find a basic purpose in my life?',
#  'Are bees born fully grown?',
#  'How legit is www.blippar.com?',
#  'Can a hermaphrodite impregnate itself? If so, how?',
#  'How do your taste buds become swollen?',
#  'Do some women really like swallowing semen? Why or why not?',
#  'What is your plan for the new year?',
#  "What's the best and most accurate way to check my IQ online for free?",
#  'What is the difference between Data Analytics, Data Analysis, Data Mining, Data Science, Machine Learning, and Big Data?',
#  'What is the difference between an agnostic and an atheist?',
#  'How is rent regulated in New York City?',
#  "I'm fat. How do I lose weight?",
#  'Which subjects are important to become a chartered accountant?',
#  'What is your review of Slide (company)?',
#  "How is the word 'advice' used in a sentence?",
#  'Deloitte US or deloitte india?',
#  'Are there any Progressive Islam dating websites?',
#  'The factors that an investor would consider before investing in the equity markets?',
#  'What are these mushrooms? Could they be truffles?',
#  'What does it feel like to tear your ACL?',
#  'How do you stay away from politics?',
#  'How is m/s/s mathematically equivalent to m/s^2?',
#  "What happens if I don't put a return address on an envelope and drop it in the box?",
#  'What is the process of casting and directing child actors in powerful films?',
#  'What are some unexpected things first-time visitors to São Tomé and Príncipe notice?',
#  'How good is Infant Jesus college of engineering, Thoothukudi?',
#  'How is AWS code commit?',
#  'What is the best way to identify a plant with a picture?',
#  'Why is Hong Kong dying?',
#  'Have mages been scientifically tested?',
#  'Which is the programming language does Windows written in?',
#  'Homework Question: How do I write a program that produces the following output?',
#  'How do I trace a phone call?',
#  'Are there any graduate scholarships for the field of computational linguistics in America?',
#  'What is the integral of [math]\\frac{x}{\\log x}[/math]?',
#  'Why does my mum spend so much time using Quora?',
#  'Is there any Part time universities in Hamburg where we can pursue MS?',
#  'Is boycotting foreign goods ethical?',
#  'What are first and second laws of thermodynamics?',
#  'Why do cats get scared when you place a cucumber in front of it?',
#  'Is it worth it to become an investment banker?',
#  'How much should I sell my domain name for?',
#  'What are some alternatives to sign-up with email confirmation?',
#  'What are some things new employees should know going into their first day at Universal?',
#  'What is the difference between Windows and Linux for web hosting?',
#  'Is there such thing as chairs for people with scoliosis?',
#  'Is it more appropriate to say "on October" or "in October"?',
#  'My sister is not being given her MBA degree because a professor in her university is not letting her get the minimum cgpa. What can we do?',
#  'What is impulse savings?',
#  'Is it safe to take antibiotics and Benadryl together?',
#  'What is the difference between licensing something by  "OS Instance" vs. "Application Instance"?',
#  'How are you so badass?',
#  "What happens if I don't pay the negative balance of a saving account?",
#  'Which university should I refer in between Stratford and Wilmington universities?',
#  "Why don't Indians practise yoga and achieve Siddhis like precognition and teleportation rather than becoming slaves to Western culture?",
#  'What are the best ways to make money online?',
#  'Why Delhi has high gun crime rates?',
#  'Who was strongest in the Force: Darth Vader, Emperor Palpatine, or Yoda?',
#  'How is zero gravity environment created on earth for astronaut training?',
#  'Is Gujarat really a developed state, or it is all hype?',
#  'Why is my optional Question Details on Quora limited but some people are not?',
#  "How do I let go of people that don't matter?",
#  'How many protons, neutrons, and electrons does lithium have?',
#  'How do salons deal with appointment cancellations?',
#  'Why was the Fourteenth Amendment necessary in the US Constitution?',
#  'Any recommended tennis racquets for someone with mild tennis elbow?',
#  "How were the Nazis capable of the murder of 11 million people and didn't break down psychologically?",
#  'How do I make a portfolio?',
#  'Should India go for another war with Pakistan?',
#  'How do I apply for a job in the Trump administration?',
#  'Is there a genealogical degree?',
#  'How upload a picture on Quora?',
#  'What made the TV show Friends a classic?',
#  'What are all the flavors of Native American Spirit Cigarettes, and what do the colors mean?',
#  'What are some lesser-known sights to see when visiting Toruń, Poland?',
#  'Why do people drink alcohol if it is bad?',
#  'What is the best book on material science and metallurgy?',
#  'What are the things you should do for your best friend?',
#  "Who's the most known person in the world?",
#  'Why does God has gone to this length to create the whole universe and a planet only for humans when the end is so inevitable?',
#  'How can we find the best SEO service provider company in India?',
#  'How do I change Windows 10 is to Android?',
#  'Which AngularJS 1.x-friendly JavaScript libraries implement infinite scrolling, filtering, sorting, and injection of new data by subscription?',
#  'Why is Saltwater Taffy candy imported in Hong Kong?',
#  'What are some things new employees should know going into their first day at Busey Bank?',
#  'How can I find the minimum number of swaps required to sort an array?',
#  'What is a list of superforecasters?',
#  'What are the 6 divisions of GEMA?',
#  'How many names had Arjun?',
#  'Is the conspiracy theory about shape-shifting reptilian people on earth true?',
#  'What are the best ways to get laid in India?',
#  'What are the chances of getting pregnant 1 week before your period?',
#  'What are some good courses that I can take on psychology from Coursera, EdX etc.?',
#  'Wisconsin Football Live Stream | Watch Wisconsin Badgers Football Game Today Live Streaming Online?',
#  'What are the primary components of a computer?',
#  'What is the exact difference between ride and drive?',
#  'What day in your life did you consider to be the best day ever?',
#  'How likely is a nuclear war with Russia in the next few years?',
#  'Is it impossible to be on the Mr. Olympia stage without taking any drugs?',
#  'What is contained in green coffee that helps you lose weight?',
#  'What does Gary Johnson have to do to have a chance of winning in November?',
#  'Where can I get professional photo booths service in Sydney?',
#  'How can I get an engineering job in Auckland?',
#  'Why did Barack Obama join Quora?',
#  'What are the best Kannada bhavageethe?',
#  "What's the difference between Conditional probability and Bayes's theorem? How to know when to apply related concept?",
#  'How will Donald Trump benefit India?',
#  'What grade or level equivalent could a student potentially reach on completion of the syllabus on PianoMarvel, Playground Sessions or Musiah?',
#  "What will be repercussion of India's surgical strike to Pakistan?",
#  'How does Three parent baby techniques formed?',
#  'Where can I get exceptional services for interior and exterior painting in Sydney?',
#  'Are ideas more important than persons?',
#  'In the xy-plane, what is the length of the shortest path from (0,0) to (12, 16) that does not go inside the circle (x -6) 2 + (y -8) 2 = 25?',
#  'Why do people support Hillary Clinton when she is a known criminal?',
#  'Should you pop herpes blisters? Why or why not?',
#  'Is it legal to bring 2-3 bottles of liquor outside of Goa?',
#  "What's the best way to learn core java?",
#  'Is there a quota when writing lines of code in the industry?',
#  'Can you name some interesting topics to write an article for college magazine?',
#  "How do you stay fit if you don't like the gym?",
#  'How can I play and import GameCube games on my NTSC Wii? Can I use GeckoOS?',
#  'What are some good survey questions to determine if someone is a good or bad credit risk?',
#  'What is the meaning of financial studies/research in academic background?',
#  'How does Quora topic gets assigned to a question automatically?',
#  'Will trump win as president?',
#  'How fast is universe expanding compared to light speed?',
#  'How are bra sizes measured?',
#  'Why do people not follow other people back on Instagram?',
#  'What are the common mistakes of language learners?',
#  'Do the new notes in India need the GPS chip?',
#  'How much does a freelance data entry operator earn on average in India if he gets a job via oDesk or Elance?',
#  'What are the best books on Joseph Goebbels?',
#  'Can someone translate those pictures from Arabic to English?',
#  'What is the difference between star & delta connection in 3 phase system?',
#  'How do you fix scratches of bike?',
#  "What are good gifts for a foreign visitor to bring when they're invited to someone's home in the Gambia for the first time?",
#  "What was the name of Sitamata's mother who was the wife of Raja Janak?",
#  'My mechanic friend had permission to work on a vehicle but the owner filed on him for unauthorized use of a motor vehicle. What should he do?',
#  'How do people from India join ISIS?',
#  'Why does ₹2.5 lak cr worth of tax benefits and loan were waived of for cooperate but when it comes to farmer they say it will increase inflation each?',
#  'Microeconomics: What is the difference between opportunity costs and implicit costs?',
#  'What is the fastest way to learn something?',
#  'How dangerous is the dark web?',
#  'What is the best format for seo Reporting to a client? It will be great help if anybody can provide a sample Report or a link from where it can be seen.',
#  'What is the deadline to complete aspire 2016?',
#  'What are the highest paid jobs in India?',
#  'How can I control some website variables using Arduino and the GSM module?',
#  'How do I create a strong fantasy world?',
#  'Who is going to win the 2016 US presidential election? Why?',
#  'Who are the best entrepreneur?',
#  ...]

# %%
# no necessari?
q1_train =  cast_list_as_strings(list(tr_df["question1"]))
q2_train =  cast_list_as_strings(list(tr_df["question2"]))
questions = q1_train+q2_train

# %%
import sklearn.feature_extraction
h = sklearn.feature_extraction.FeatureHasher(input_type ='string')
#f = h.transform(questions) # to get a scipy.sparse matrix X

# %%
def get_features_from_df(df, featurehash):
    """
    returns a sparse matrix containing the features build by the count vectorizer.
    Each row should contain features from question1 and question2.
    """
    q1_casted =  cast_list_as_strings(list(df["question1"]))
    q2_casted =  cast_list_as_strings(list(df["question2"]))
    
    ############### Begin exercise #################
    # what is kaggle                  q1
    # What is the kaggle platform     q2
    X_q1 = featurehash.transform(q1_casted)
    X_q2 = featurehash.transform(q2_casted)    
    X_q1q2 = scipy.sparse.hstack((X_q1,X_q2))
    ############### End exercise ###################

    return X_q1q2

# %%
X_tr_q1q2 = get_features_from_df(tr_df, h) # it converts list as strings

# %%
# training a simple model
logistic = sklearn.linear_model.LogisticRegression(solver="liblinear",
                                                   random_state=123)
logistic.fit(X_tr_q1q2, y_train)
# Out:
# LogisticRegression(random_state=123, solver='liblinear')

# %%
evaluate_model(X_tr_q1q2, y_train, model=logistic, display=True)
# Out:
# METRICS:
#  ------------------------------------------------------------------------------------------
# Accuracy:  0.6637718099192523
# F1:  0.3861088871096877
# Precision:  0.5904386585809117
# Recall:  0.28684281452429855
# ROC AUC:  0.5853388453244179
#
#  CLASSIFICATION REPORT:
#  ------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#     Negative       0.68      0.88      0.77    184298
#     Positive       0.59      0.29      0.39    107599
#
#     accuracy                           0.66    291897
#    macro avg       0.64      0.59      0.58    291897
# weighted avg       0.65      0.66      0.63    291897
#
# CONFUSION MATRIX:
#  ------------------------------------------------------------------------------------------
# {'accuracy': 0.6637718099192523,
#  'roc_auc': 0.5853388453244179,
#  'precision': 0.5904386585809117,
#  'recall': 0.28684281452429855,
#  'f1': 0.3861088871096877}

# %%
# features provar amb diferent models
# volem triar features? -- amb sparce complicat (no)
# provar fetures amb diferents distancies
# provar features amb TF IDF en comptes de count vectorizer
##########
# cosine and eucledian similarity
# word embeddings, entrenar model
# word embeddings + features + distances
# mirar amb diferents models
# mirar models amb distancies d'embeddings (ex. siamese models)
##########
# pretrained LM (sentance embeddings) (?)
# pretranied LM for QUORA CHALLENGES

# %% [markdown]
# Quite bad performance with feature hashing.

# %% [markdown]
# - cosine vs eucledian distance
# - nearest neighbour search
# - the hashing trick (feature hashing), LSH
# - siamese model !!!
